# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menu bar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menu bar, select Cell$\rightarrow$Run All).
#
# Make sure that in addition to the code, you provide written answers for all questions of the assignment.
#
# Below, please fill in your name and collaborators:

# %%
NAME = "Raghav Sharma"
COLLABORATORS = ""

# %% [markdown]
# ## Assignment 2 - Data Analysis using Pandas
# **(15 points total)**

# %% [markdown]
# For this assignment, we will analyze the open dataset with data on the passengers aboard the Titanic.
#
# The data file for this assignment can be downloaded from Kaggle website: https://www.kaggle.com/c/titanic/data, file `train.csv`. It is also attached to the assignment page. The definition of all variables can be found on the same Kaggle page, in the Data Dictionary section.
#
# Read the data from the file into pandas DataFrame. Analyze, clean and transform the data to answer the following question:
#
# **What categories of passengers were most likely to survive the Titanic disaster?**

# %% [markdown]
# **Question 1.**  _(4 points)_
# * The answer to the main question - What categories of passengers were most likely to survive the Titanic disaster? _(2 points)_
# * The detailed explanation of the logic of the analysis _(2 points)_
#
# **Question 2.**  _(3 points)_
# * What other attributes did you use for the analysis? Explain how you used them and why you decided to use them.
# * Provide a complete list of all attributes used.
#
# **Question 3.**  _(3 points)_
# * Did you engineer any attributes (created new attributes)? If yes, explain the rationale and how the new attributes were used in the analysis?
# * If you have excluded any attributes from the analysis, provide an explanation why you believe they can be excluded.
#
# **Question 4.**  _(5 points)_
# * How did you treat missing values for those attributes that you included in the analysis (for example, `age` attribute)? Provide a detailed explanation in the comments.

# %% [markdown]
#     To start the analysis it is important to import the generic libraries that will allow us to do so. The default libraries are imported here.
#
#
#     Followed by reading the csv file.

# %%
import pandas as pd
import numpy as np

# %%
titantic_data = pd.read_csv("train.csv")

# %% [markdown]
#     Firstly, getting a high level view of the DataFrame

# %%
titantic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# The columns are self explanatory with the exception to:
# 1. Pclass - Passenger Class
# 2. SibSp - # Siblings or Spouses
# 3. Parch - # Parents or Childrens
#
# On first view, we can see that there is some missing data for Cabin, Embarked, Age. We will have two seperate treatments for these columns.
# 1. Cabin has a substantial number of values missing. So we will be dropping that column
# 2. Age and Embarked have most of the values available (80.13% and 99.77% of total records). We will remove the rows with missing Age and/or Embarked
#
# Additionally, Name, Ticket and PassengerID are unique per row. Which means, we will not be able to aggregate the data. We will be dropping those Columns as well

# %%
t_cleaned_columns = titantic_data.drop(["PassengerId","Ticket","Cabin","Name"],axis=1)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
t_cleaned_final = t_cleaned_columns.dropna();
t_cleaned_final
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 885         0       3  female  39.0      0      5  29.1250        Q
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [712 rows x 8 columns]

# %%
t_cleaned_final.corr(method="pearson")
t_survived = t_cleaned_final[t_cleaned_final.Survived == 1]
t_survived
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 8           1       3  female  27.0      0      2  11.1333        S
# 9           1       2  female  14.0      1      0  30.0708        C
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 875         1       3  female  15.0      0      0   7.2250        C
# 879         1       1  female  56.0      0      1  83.1583        C
# 880         1       2  female  25.0      0      1  26.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 889         1       1    male  26.0      0      0  30.0000        C
#
# [288 rows x 8 columns]
